# %% [markdown]
# # Homework 2
#
# ϞϞ(๑⚈ ․̫ ⚈๑)
#
# The latest pokedex update added a cool new feature: the `Last Seen` column, which tells us when we last encountered each pokemon. We want to analyse our historical data to better understand how to catch them all!
#
# The data can be found under `pokedex_v2/pokemons.csv`, and is the same as homework 1 (with the added column).

# %% [markdown]
# ## Problem 1
#
# Since we want to analyse historical data, let's work in the time domain. We want a sorted log of all our last pokemon encounters, indexed by time of last encounter.
#
# 💪 **Task: Load the DataFrame in a variable called `df`, index the DataFrame by `Last Seen` timestamps, then sort the DataFrame in chronological order.**
#
# Pro-tips:
# * revisit the [`.read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) documentation to understand how to parse dates correctly.
# * remember to update the `df` variable everytime you modify it

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('pokedex_v2/pokemons.csv',parse_dates=['Last Seen'])
df = df.set_index('Last Seen')
df = df.sort_index()
df.head()
# Out:
#                      Unnamed: 0    #                   Name  Type 1  Type 2  \
# Last Seen
# 2019-12-29 23:00:00          26   21                Spearow  Normal  Flying
# 2020-01-01 17:00:00          36   31              Nidoqueen  Poison  Ground
# 2020-01-02 06:00:00         144  133                  Eevee  Normal     NaN
# 2020-01-03 00:00:00          94   87                Dewgong   Water     Ice
# 2020-01-08 08:00:00         141  130  GyaradosMega Gyarados   Water    Dark
#
#                      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Last Seen
# 2019-12-29 23:00:00    262  40      60       30       31       31     70
# 2020-01-01 17:00:00    505  90      92       87       75       85     76
# 2020-01-02 06:00:00    325  55      55       50       45       65     55
# 2020-01-03 00:00:00    475  90      70       80       70       95     70
# 2020-01-08 08:00:00    640  95     155      109       70      130     81
#
#                      Generation  Legendary
# Last Seen
# 2019-12-29 23:00:00           1      False
# 2020-01-01 17:00:00           1      False
# 2020-01-02 06:00:00           1      False
# 2020-01-03 00:00:00           1      False
# 2020-01-08 08:00:00           1      False

# %% [markdown]
# <span style='color:Green'>🤩 **functional code & correct method**</span>
#
# <span style='color:Green'> Amazing usage of the parameters of `read_csv`!
#
# <span style='color:Green'> conveniently, `parse_dates[]` turns our dates into real *datatime type*
#
# <span style='color:Green'>`index_col[]` helps us set the indexing manually.(the default of indices in `read_csv()` is None, and pandas automatically creates a new column starting from 0 to the length of our dataframe.

# %%
def test_load_df():
    assert'df' in globals(), "DataFrame wasn't loaded in variable df"
    print('Success! 🎉')
    
def test_time_index():
    assert type(df.index) == pd.core.indexes.datetimes.DatetimeIndex, f"Expected DataFrame index type to be DatetimeIndex, but got {type(df.index)}"
    max_ts = pd.Timestamp("2021-01-06 08:00:00")
    assert df.index.max() == max_ts, f"Expected max timestamp in index to be {max_ts}, but got {df.index.max()}"
    print('Success! 🎉')
    
def test_sorted_index():
    assert df.index.is_monotonic_increasing, "Expected time index to be sorted by chronological order"
    print('Success! 🎉')
    
test_load_df()
test_time_index()
test_sorted_index()
# Out:
# Success! 🎉
# Success! 🎉
# Success! 🎉

# %% [markdown]
# ## Problem 2
#
# Oh dear, Misty recently borrowed our pokedex, and now we can't tell which pokemons were found by whom!
#
# 💪 **Task: Add a `Trainer` column, with value `Misty` for pokemons `Last Seen` in July 2020, and value `Me` for the rest.**
#
# Pro-tip: make sure you update the `df` object!

# %%
df['Trainer'] = "Me"
df.loc['07/2020','Trainer'] = "Misty"

# %% [markdown]
# <span style='color:Green'>🤩 **functional code & correct method**</span>
#
# <span style='color:Green'> Yup, that's right.
# by `df['Trainer']='Me'`, you created a 'Trainer' column and set every value to 'Me'.
# and by df.loc[], you chose the row in which the index is `July 2020` and updated the value of its trainer column to `'Misty`", amazing!

# %%
def test_trainer_column():
    assert "Trainer" in df.columns, "Can't find column 'Trainer'"
    print('Success! 🎉')
    
def test_misty_fix():
    na_count = (df["Trainer"] == "Misty").sum()
    assert na_count == 86, f"Misty should have seen 86 pokemons, but she has seen {na_count}" 
    print('Success! 🎉')
    
test_trainer_column()
test_misty_fix()
# Out:
# Success! 🎉
# Success! 🎉

# %% [markdown]
# ## Problem 3
#
# The most exciting part of going on trainer adventures is coming across powerful pokemons 💪. We remember some weeks where we met very strong pokemon, and some that were more quiet. We want to visualise this by tracking the `Total` characteristic of the most powerful pokemon we met in the last 7 days.
#
# 💪 **Task: Calculate a max rolling statistic for the `Total` variable with window size of 7 days. Store it in a Series called `rolling_max_total`.**
#
# Pro-tip: revisit the [`.rolling`] documentation to understand the difference between windows defined by number of steps, and windows defined by amount of time.

# %%
rolling_max_total = df['Total'].rolling('7d').max()
# The offset notation is confusing, 
#   couldn't find a proper documentation on pandas neither python should maybe search in datetime docs

# %% [markdown]
# <span style='color:Green'>🤩 **functional code & correct method**</span>
#
# <span style='color:Green'> Top!
# The `rolling()` method in pandas helps us easily operate on sub periods of your time series(7 days, in our case). In particular, window functions calculate metrics for the **data inside the window**. Then, the result of this calculation forms a **new time series**(`rolling_max_total` in this case), where each data point represents a **summary of several data points** of the original time series.

# %% [markdown]
# <span style='color:Green'> And for documentations, these are some resources you can check out:
#
# <a href= https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rolling.html>Official Documentation </a>
#
# <a href=https://towardsdatascience.com/dont-miss-out-on-rolling-window-functions-in-pandas-850b817131db> Rolling Window Functions</a>

# %%
def test_rolling_max_total():
    assert'rolling_max_total' in globals(), "Can't find variable rolling_max_total"
    assert type(rolling_max_total) == pd.Series, f"Expected `rolling_max_total` to be a Series object, but got {type(rolling_max_total)}"
    assert type(rolling_max_total.index) == pd.core.indexes.datetimes.DatetimeIndex, f"Expected DataFrame index type to be DatetimeIndex, but got {type(rolling_max_total.index)}"
    assert len(rolling_max_total) == 800, f"Expected length of rolling_max_total to be 800, but got {len(rolling_max_total)}"
    assert rolling_max_total.sum() == 532758, f"Expected sum of rolling_max_total to be 532758, but got {rolling_max_total.sum()}"
    print('Success! 🎉')

test_rolling_max_total()
# Out:
# Success! 🎉

# %% [markdown]
# 💪 **Task: Visualise this rolling statistic through time.**
#
# The code cell below should return the graph:
#
#
# Pro-tip: pimp up your graph!

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (0.11.1)
# Requirement already satisfied: scipy>=1.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from seaborn) (1.7.0)
# Requirement already satisfied: matplotlib>=2.2 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: numpy>=1.15 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from seaborn) (1.21.0)
# Requirement already satisfied: pandas>=0.23 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from seaborn) (1.2.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.1)

# %%
import seaborn as sns
sns.set_theme()
rolling_max_total.plot.line(ylabel='Max', figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Last Seen', ylabel='Max'>

# %% [markdown]
# <span style='color:Green'>🤩 **functional code & correct method**</span>
#
# <span style='color:Green'>Seaborn looking goooood! Keep in mind that a good graph is one that can be taken out of context and still make sense ... a title could help complete the picture here.</span>

# %% [markdown]
# 🧠 **Question: Do you have an idea why the graph looks different between March and May?**

# %%
df.loc['03/2020':'04/2020']
# Out:
#                      Unnamed: 0    #               Name    Type 1    Type 2  \
# Last Seen
# 2020-03-04 01:00:00         137  127  PinsirMega Pinsir       Bug    Flying
# 2020-03-12 09:00:00          72   66             Machop  Fighting       NaN
# 2020-04-18 22:00:00         191  177               Natu   Psychic    Flying
# 2020-04-25 09:00:00         185  171            Lanturn     Water  Electric
#
#                      Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Last Seen
# 2020-03-04 01:00:00    600   65     155      120       65       90    105
# 2020-03-12 09:00:00    305   70      80       50       35       35     35
# 2020-04-18 22:00:00    320   40      50       45       70       45     70
# 2020-04-25 09:00:00    460  125      58       58       76       76     67
#
#                      Generation  Legendary Trainer
# Last Seen
# 2020-03-04 01:00:00           1      False      Me
# 2020-03-12 09:00:00           1      False      Me
# 2020-04-18 22:00:00           2      False      Me
# 2020-04-25 09:00:00           2      False      Me

# %% [markdown]
# The number of pokemon catched was low, therefore calculating a rolling maximum is non relevant.

# %% [markdown]
# <span style='color:Green'>🤩 **correct answer**</span>
#
# <span style='color:Green'> Exactly. If you wanted, you could even exclude that data with: the `min_periods` argument to [`.rolling()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html).

# %% [markdown]
# ## Problem 4
#
# We started our journey a while ago, and have explored 6 entire generations of Pokemon. We'd like to visualise this journey by plotting a _histogram_ of our last pokemon encounters, grouped by `Generation`.
#
# 💪💪 **Task: Plot a histogram of pokemon encounters through time grouped by `Generation`.**
#
# Pro-tips:
# * The x-axis should be time.
# * Each group should be represented with a different visual encoding
# * check out [.hist()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html#matplotlib.pyplot.hist)
# * pimp up your graph!
#
# The graph should be displayed by the code cell below:

# %%
import matplotlib.pyplot as plt

df_by_generation = df.groupby('Generation')

fig, ax = plt.subplots(1,1,figsize=(10,10))

for name, group in df_by_generation :
    label = "Generation " + str(name)
    ax.hist(group.index,label=label,histtype = 'barstacked')
    
ax.legend()
ax.set_title("Number of pokemon captured by generation")
# Out:
# Text(0.5, 1.0, 'Number of pokemon captured by generation')

# %% [markdown]
# <span style='color:Green'>🤩 **functional code & correct method**</span>
#
# <span style='color:Green'>Great looking graph! If you wanted the most recent bars to not "hide" the previous groups, you can use the `alpha` argument to `.hist()` to make them slightly transparent.

# %% [markdown]
# ## Problem 5
#
# Our pokedex updated its database with new pokemon pictures... but accidentally flipped all of them upside down! Let's fix this:
#
# 💪💪 **Task: Iterate through the pokemon images in the `images` directory, flip them the right side up, then save them in the directory called `images_flipped`.**
#
# Pro-tips:
# * to iterate through system files in python, check out [`glob`](https://docs.python.org/3/library/glob.html)
# * [`os.path`](https://docs.python.org/3/library/os.path.html) has some great filename utilities

# %%
import os                                                                   
import glob
import errno
from PIL import Image
import matplotlib.pyplot as plt

try :
    os.mkdir('./images_flipped')
except OSError as exception:
    if exception.errno != errno.EEXIST:
        raise

for file in list(glob.glob('./images/*.png')):
    image = Image.open(file)
    image_flip = image.transpose(Image.FLIP_TOP_BOTTOM)
    image_flip.save("./images_flipped/" + os.path.basename(file))

# %% [markdown]
# <span style='color:Green'>🤩 **functional code & correct method**</span>
#
# <span style='color:Green'> yup, Pillow to the rescue!
#
# <span style='color:Green'> Smart usage of basename to get the name of each image.
# It's cool that you configured an error-handler as well, smart!

# %%
from PIL import Image

def test_image_flip():
    image = Image.open("images_flipped/17.png")
    pixel = image.getpixel((143, 125))
    expected_pixel = (200, 188, 151, 255)
    assert pixel == expected_pixel, f'Image 43.png not flipped. Expected values {expected_pixel} at pixel (143, 125), but got {pixel}'
    print('Success! 🎉')


test_image_flip()
# Out:
# Success! 🎉

# %% [markdown]
# ## Problem 6
#
# Flipping through those Pokemon images got us nostalgic, so we listen to the Pokemon theme tune. We marvel at the simple and effective linguistic construction of this poetic masterpiece: verbs are often repeated in the lyrics to emphasize the importance of our Pokemon trainer mission. What is the verb that is most often repeated?
#
# 💪  **Task: Open the `lyrics.txt` file, and analyse it with `spacy`'s english `nlp` model. Store the result in a variable called `doc`.**
#
# Pro-tip: You might need to download the spacy model just like we did in lecture 2.2.

# %%
# !python -m spacy download en
# Out:
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 15.6 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.61.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: setuptools in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (56.0.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.4)
# Requirement already satisfied: numpy>=1.15.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.21.0)
# Requirement already satisfied: pathy>=0.3.5 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.6.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.25.1)
# Requirement already satisfied: jinja2 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (5.1.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.26.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.0.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/camille/.local/share/virtualenvs/pds-solutions-ChBxshhE/lib/python3.9/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

with open('lyrics.txt', 'r') as f:
    content = f.read()

doc = nlp(content)

# %% [markdown]
# <span style='color:Green'>🤩 **functional code & correct method**</span>
#
# <span style='color:Green'> Great job! `en_core_web_sm` is a small language model that SpaCy provides us with.
#
# <span style='color:Green'>By creating a `doc` object, we can distinguish the parts of speech (POS_) and lemmatize (Lem_) each token!

# %%
def test_doc():
    assert "doc" in globals(), "Couldn't find a variable called doc"
    assert len(doc) == 388, f"Expected 388 tokens in doc, but got {len(doc)}"
    print('Success! 🎉')
    
test_doc()
# Out:
# Success! 🎉

# %% [markdown]
# 💪💪 **Task: Find the most common verb in `doc`**
#
# The code cell below should print out the most common verb:
#
# Pro-tips:
# * "VERB" is a [_part of speech_](https://spacy.io/usage/linguistic-features#pos-tagging), which you can directly check on tokens.
# * using [_lemmas_](https://spacy.io/usage/linguistic-features#lemmatization) instead of raw token text allows to normalise variations (like verb conjugations)
# * [`Counter`](https://pymotw.com/2/collections/counter.html) is an easy way to count repeated elements in collections.

# %%
from collections import Counter

verbs = [token.lemma
         for token in doc
         if (not token.is_stop and not token.is_punct and token.pos_ == "VERB")]

verb_freq = Counter(verbs)
print("The most common verb in lyrics.txt is '", [token.text for token in doc if token.lemma == verb_freq.most_common(1)[0][0]][0] , "' and it is used ", verb_freq.most_common(1)[0][1] ," times")
# Out:
# The most common verb in lyrics.txt is ' Got ' and it is used  12  times

# %% [markdown]
# <span style='color:Green'>🤩 **functional code & correct method**</span>
#
# <span style='color:Green'>smart usage of `.lemma_` and `.pos_` in the list comprehension to store all the verbs in `verb`. I would probably take that last list comprehension out of the print statement, just so that the last line is more legible. You can also check out [python f strings](https://realpython.com/python-f-strings/) for a neat way of printing out variables.

# %% [markdown]
# 💪💪 **Bonus Task: Visualise the distribution of verb counts in the lyrics.**
#
# Pro-tip: check out [data to viz](https://www.data-to-viz.com/) to pick the most effective chart type.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS 

stopwords = set(STOPWORDS)
verbs_distrib = [token.text
                 for token in doc
                 if (not token.is_stop and not token.is_punct and token.pos_ == "VERB")]
big_string = ' '.join(verbs_distrib)
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(big_string) 

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud)

# %% [markdown]
# But according to Data to viz most optimal way to display this distribution is with bar chart :

# %%
from collections import Counter

verbs_freq = Counter(verbs_distrib)
df_verb = pd.DataFrame({'group': verbs_freq.keys(),'values': verbs_freq.values()})
df_verb = df_verb.sort_values(by='values')

plt.hlines(y=range(1,len(df_verb.index)+1), xmin=0, xmax=df_verb['values'])
plt.plot(df_verb['values'], range(1,len(df_verb.index)+1), "o")
plt.yticks(range(1,len(df_verb.index)+1), df_verb['group'])

plt.xlabel('Number of occurence')
plt.ylabel('Verbs')
plt.show()

# %% [markdown]
# <span style='color:Green'>🤩 **functional code & correct method**</span>
#
# <span style='color:Green'> You are right :) Word clouds are useful when we want to emphasis on the importance of a certain word in a "graphic" way. but it doesn't show us as much quantitative info as a bar chart which you've done below.

# %% [markdown]
# <span style='color:Green'>**Feedback: 🤩**</span>
#
# <span style='color:Green'>
#     Excellent work Amine! You are clearly comfortable with pandas, and with image/text handling in python.</span>
